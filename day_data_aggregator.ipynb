# %%
import pandas as pd 
import glob
pd.options.mode.chained_assignment = None  # default='warn'
all_day_files = glob.glob("day_data/*.csv")
data_frames = []
for file_name in all_day_files:
    df = pd.read_csv(file_name, dtype={'favorite_payload': str})
    df['day_file'] = file_name
    data_frames.append(df) 

def find_mode(series):
    mode_df = series.mode()
    if not mode_df.empty:
        return mode_df.iloc[0]
    else:
        return pd.NA  # Return NaN if no mode is found
        
combined_df = pd.concat(data_frames, ignore_index=True)
aggregations = {
    'subnet': ('subnet', 'first'),
    'active_days': ('day_file', 'nunique'),
    'asn': ('asn', 'first'), 
    'country': ('country', 'first'),
    'city': ('city', 'first'),
    'scan_length_seconds': ('scan_length_seconds', 'mean'),
    'median_time_diff': ('median_time_diff', 'mean'),
    'distinct_src_ports': ('distinct_src_ports', 'mean'),
    'distinct_dest_ports': ('distinct_dest_ports', 'mean'),
    'q1_prev_ip': ('q1_prev_ip', 'mean'),
    'median_prev_ip': ('median_prev_ip', 'mean'),
    'q3_prev_ip': ('q3_prev_ip', 'mean'),
    'distinct_ips': ('distinct_ips', 'mean'),
    'total_hits': ('total_hits', 'mean'),
    'probes_per_ip': ('probes_per_ip', 'mean'),
    'distinct_fingerprints': ('distinct_fingerprints', 'mean'),
    'distinct_payloads': ('distinct_payloads', 'mean'),
    'avg_payload_length': ('avg_payload_length', 'mean'),
    'q1q3_delta': ('q1q3_delta', 'mean'),
    # find most frequent value
    'top_port': ('top_port', find_mode),
    'top_fingerprint': ('top_fingerprint', find_mode),
    'generation_algorithm': ('generation_algorithm', find_mode),
    'top_start_hour': ('start_hour', find_mode),
    'top_end_hour': ('end_hour', find_mode)
}

aggregated_df = combined_df.groupby('src_ip').agg(**aggregations).reset_index()
clean_df = aggregated_df.dropna(subset=['median_time_diff'])
clean_df.to_csv('3_weeks.csv')
print(clean_df)
# Out:
#               src_ip        subnet  active_days      asn country  \
# 0       1.681231e+07  1.681229e+07            3  23969.0      TH
# 1       1.681427e+07  1.681408e+07            2  23969.0      TH
# 2       1.681438e+07  1.681434e+07            1  23969.0      TH
# 3       1.681454e+07  1.681434e+07            1  23969.0      TH
# 4       1.681460e+07  1.681459e+07            2  23969.0      TH
# ...              ...           ...          ...      ...     ...
# 921886  3.758089e+09  3.758089e+09            1  45727.0      ID
# 921887  3.758090e+09  3.758089e+09            1  45727.0      ID
# 921888  3.758090e+09  3.758090e+09            1  45727.0      ID
# 921889  3.758090e+09  3.758090e+09            1  45727.0      ID
# 921890  3.758093e+09  3.758093e+09            1  45117.0      IN
#
#                  city  scan_length_seconds  median_time_diff  \
# 0       Nakhon Pathom               9670.0            3000.0
# 1         Khlong Thom              39334.0         1189000.0
# 2         Khlong Thom               1384.0          346000.0
# 3         Khlong Thom               3084.0          814000.0
# 4         Khlong Thom              21232.5         1607000.0
# ...               ...                  ...               ...
# 921886        Mataram                  3.0            3000.0
# 921887        Jakarta               2362.0            3000.0
# 921888         Bekasi                  3.0            3000.0
# 921889         Bekasi               4598.0          586000.0
# 921890           None                  7.0            2000.0
#
#         distinct_src_ports  distinct_dest_ports  ...  probes_per_ip  \
# 0                 3.666667                  1.0  ...            2.0
# 1                16.500000                  2.0  ...            1.0
# 2                 5.000000                  2.0  ...            1.0
# 3                 4.000000                  2.0  ...            1.0
# 4                 2.000000                  1.0  ...            1.0
# ...                    ...                  ...  ...            ...
# 921886            1.000000                  1.0  ...            2.0
# 921887            4.000000                  1.0  ...            2.0
# 921888            1.000000                  1.0  ...            2.0
# 921889            5.000000                  1.0  ...            1.4
# 921890            1.000000                  1.0  ...            4.0
#
#         distinct_fingerprints  distinct_payloads  avg_payload_length  \
# 0                         1.0                1.0                 0.0
# 1                         1.0                1.0                 0.0
# 2                         1.0                1.0                 0.0
# 3                         1.0                1.0                 0.0
# 4                         1.0                1.0                 0.0
# ...                       ...                ...                 ...
# 921886                    1.0                1.0                 0.0
# 921887                    1.0                1.0                 0.0
# 921888                    1.0                1.0                 0.0
# 921889                    1.0                1.0                 0.0
# 921890                    1.0                1.0                 0.0
#
#           q1q3_delta  top_port  top_fingerprint  generation_algorithm  \
# 0       5.845667e+03    5900.0             11.0                   6.0
# 1      -1.146002e+08      80.0              3.0                   5.0
# 2       1.796343e+07      80.0              3.0                   6.0
# 3      -1.796621e+07      80.0              3.0                   5.0
# 4      -1.146161e+08    2323.0             10.0                   5.0
# ...              ...       ...              ...                   ...
# 921886  0.000000e+00    5900.0             11.0                   4.0
# 921887  2.472323e+08    5900.0             11.0                   6.0
# 921888  0.000000e+00    5900.0             11.0                   4.0
# 921889 -4.170000e+03    5900.0             11.0                   5.0
# 921890  0.000000e+00    5555.0              4.0                   4.0
#
#         top_start_hour  top_end_hour
# 0                  1.0           9.0
# 1                  0.0          22.0
# 2                 23.0          23.0
# 3                 23.0          23.0
# 4                  0.0           2.0
# ...                ...           ...
# 921886            15.0          15.0
# 921887             9.0          10.0
# 921888             4.0           4.0
# 921889             5.0           6.0
# 921890             8.0           8.0
#
# [921846 rows x 25 columns]

# %%
gen1 = aggregated_df[aggregated_df['active_days'] == 6]
print(gen1)
# Out:
#             src_ip      subnet  active_days    asn country        city  \
# 244       16962648    16962560            6  23969      TH  Nonthaburi
# 372       17470127    17469952            6  23969      TH     Bangkok
# 570       18205419    18205184            6   2519      JP     Okazaki
# 571       18250766    18250752            6  45528      IN      Kanpur
# 936       18432435    18432256            6   4837      CN        None
# ...            ...         ...          ...    ...     ...         ...
# 921076  3754409980  3754409728            6   4134      CN        None
# 921083  3754692472  3754692352            6  45758      TH   Khon Kaen
# 921154  3754781820  3754781696            6  45758      TH       Trang
# 921239  3754882623  3754882560            6  45758      TH   Khon Kaen
# 921508  3756605881  3756605696            6  24560      IN       Delhi
#
#         scan_length_seconds  median_time_diff  distinct_src_ports  \
# 244            60602.000000      1.211667e+06            4.000000
# 372            64952.666667      2.500000e+03           25.500000
# 570            34873.166667      1.502000e+06            1.833333
# 571            65754.166667      3.433333e+05            1.000000
# 936            79358.000000      2.572667e+06           18.500000
# ...                     ...               ...                 ...
# 921076         18491.833333      1.495833e+05            6.500000
# 921083         70782.666667      2.308250e+06            1.000000
# 921154         46230.333333      7.886667e+05            3.666667
# 921239         80910.166667      1.656000e+06           33.500000
# 921508         22124.666667      1.833333e+03           14.333333
#
#         distinct_dest_ports  ...  distinct_ips  total_hits  probes_per_ip  \
# 244                1.000000  ...     25.833333   25.833333       1.000000
# 372                7.166667  ...     25.500000  101.166667       3.978009
# 570                2.166667  ...     17.166667   17.166667       1.000000
# 571                1.000000  ...    124.000000  155.500000       1.166667
# 936                1.000000  ...     25.166667   25.333333       1.005051
# ...                     ...  ...           ...         ...            ...
# 921076             6.500000  ...      6.500000    6.500000       1.000000
# 921083             1.000000  ...     26.666667   26.666667       1.000000
# 921154             1.000000  ...     49.666667   49.666667       1.000000
# 921239             2.000000  ...     33.500000   33.500000       1.000000
# 921508             1.000000  ...     13.833333  157.666667      11.487118
#
#         distinct_fingerprints  distinct_payloads  avg_payload_length  \
# 244                       1.0                1.0                 0.0
# 372                       1.0                1.0                 0.0
# 570                       1.0                1.0                 0.0
# 571                       1.0                1.0                 0.0
# 936                       1.0                1.0                 0.0
# ...                       ...                ...                 ...
# 921076                    1.0                1.0                 0.0
# 921083                    1.0                1.0                 0.0
# 921154                    1.0                1.0                 0.0
# 921239                    1.0                1.0                 0.0
# 921508                    1.0                1.0                 0.0
#
#           q1q3_delta  top_port  top_fingerprint  generation_algorithm
# 244     7.642667e+03      1433               11                     6
# 372     0.000000e+00        80                4                     4
# 570    -3.820710e+07      4719               10                     5
# 571     2.989761e+06     37215               10                     5
# 936     3.520053e+07      5555               10                     5
# ...              ...       ...              ...                   ...
# 921076  1.146095e+08      1201               11                     5
# 921083 -8.987322e+06      2323               10                     5
# 921154 -4.116627e+07      2323               10                     5
# 921239  2.990805e+06      8080                3                     5
# 921508  0.000000e+00        21               11                     4
#
# [14467 rows x 23 columns]
